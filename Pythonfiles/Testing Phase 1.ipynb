# %%
from tabula import read_pdf

# %%
from tabulate import tabulate

# %%
import PyPDF2 as pdf
import re

# %% [markdown]
# # Aurobinda Pharma for 2017-18

# %%
import PyPDF2 as pdf
import re

# open the pdf file
object = pdf.PdfFileReader("Annual-Report-2017-18.pdf")

# get number of pages
NumPages = object.getNumPages()

# define keyterms
String = "CONSOLIDATED BALANCE SHEET"
String1 = "STANDALONE STATEMENT OF PROFIT AND LOSS"
String2 = "STANDALONE STATEMENT OF CASH FLOW"
# extract text and do the search
for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
    # print(Text)
    if  re.search(String, Text) != None:
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer=pdf.PdfFileWriter()
        pdf_writer.addPage(page)
        output=open('balancesheet_aurobindo_1718.pdf','wb')
        pdf_writer.write(output)
        output.close()
        df=read_pdf('balancesheet_aurobindo_1718.pdf')
df[0]
# for i in range(0, NumPages):
#     PageObj = object.getPage(i)
#     Text = PageObj.extractText() 
#     # print(Text)
#     if  re.search(String1, Text) != None:
#         print("This is page " + str(i))
#         page=object.getPage(i)
#         pdf_writer=pdf.PdfFileWriter()
#         pdf_writer.addPage(page)
#         output=open('p&l.pdf','wb')
#         pdf_writer.write(output)
#         output.close()
        
# for i in range(0, NumPages):
#     PageObj = object.getPage(i)
#     Text = PageObj.extractText() 
#     # print(Text)
#     if  re.search(String2, Text) != None:
#         print("This is page " + str(i))
#         page=object.getPage(i)
#         pdf_writer=pdf.PdfFileWriter()
#         pdf_writer.addPage(page)
#         output=open('cashflow.pdf','wb')
#         pdf_writer.write(output)
#         output.close()
# Out:
# This is page 205
# 'pages' argument isn't specified.Will extract only from page 1 by default.
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0         NaN                                                NaN      Notes
# 1           I                                             ASSETS        NaN
# 2         NaN                                 Non-current assets        NaN
# 3         NaN                 (a)  Property, plant and equipment          3
# 4         NaN                      (b)  Capital work-in-progress          3
# 5         NaN                                      (c)  Goodwill          4
# 6         NaN                       (d)  Other intangible assets          5
# 7         NaN           (e)  Intangible assets under development          5
# 8         NaN                              (f)  Financial assets        NaN
# 9         NaN                                    (i) Investments       6(A)
# ...

# %%
print(tabulate(df[0]))
# Out:
# --  ---  -------------------------------------------------------  -----  -------------  -------------
#  0  nan  nan                                                      Notes  31 March 2018  31 March 2017
#  1  I    ASSETS                                                   nan    nan            nan
#  2  nan  Non-current assets                                       nan    nan            nan
#  3  nan  (a)  Property, plant and equipment                       3      47,365.6       40,830.5
#  4  nan  (b)  Capital work-in-progress                            3      13,995.4       12,373.6
#  5  nan  (c)  Goodwill                                            4      8,165.5        4,063.0
#  6  nan  (d)  Other intangible assets                             5      9,675.7        3,444.3
#  7  nan  (e)  Intangible assets under development                 5      1,835.0        2,207.2
#  8  nan  (f)  Financial assets                                    nan    nan            nan
# ...

# %%
# open the pdf file
object = pdf.PdfFileReader("Annual-Report-2017-18.pdf")

# get number of pages
NumPages = object.getNumPages()

String1 = "STANDALONE STATEMENT OF PROFIT AND LOSS"

for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
    # print(Text)
    if  re.search(String1, Text) != None:
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer=pdf.PdfFileWriter()
        pdf_writer.addPage(page)
        output=open('p&l_aurobindo_1718.pdf','wb')
        pdf_writer.write(output)
        output.close()
        df_pl=read_pdf('p&l_aurobindo_1718.pdf')
print(tabulate(df_pl[0]))
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# This is page 144
# --  ----  --------------------------------------------------------------------------------  ----  -------------  -------------
#  0  nan   nan                                                                               Note  31 March 2018  31 March 2017
#  1  I     INCOME                                                                            nan   nan            nan
#  2  nan   Revenue from operations                                                           20    103,031.5      97,812.1
#  3  nan   Other income                                                                      21    806.5          1,359.5
#  4  nan   TOTAL INCOME (I)                                                                  nan   103,838.0      99,171.6
#  5  II    EXPENSES                                                                          nan   nan            nan
# ...

# %%
# open the pdf file
object = pdf.PdfFileReader("Annual-Report-2017-18.pdf")

# get number of pages
NumPages = object.getNumPages()
String2 = "STANDALONE STATEMENT OF CASH FLOW"
pdf_writer=pdf.PdfFileWriter()
for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
    # print(Text)
    if  re.search(String2, Text) != None:
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer.addPage(page)
output=open('cashflow.pdf','wb')
pdf_writer.write(output)
output.close()
df_cash=read_pdf('cashflow.pdf',pages='all')
# Out:
# This is page 146
# This is page 147

# %%
df_cash
# Out:
# <TableList n=0>

# %%
import camelot
tables=camelot.read_pdf("cashflow.pdf")

# %%
tables
# Out:
# <TableList n=0>

# %%
# # open the pdf file
# object = pdf.PdfFileReader("Annual-Report-2016-17.pdf")
# # get number of pages
# NumPages = object.getNumPages()



# String2 = "STANDALONE STATEMENT OF CASH FLOW"




# for i in range(0, NumPages):
#     PageObj = object.getPage(i)
#     Text = PageObj.extractText() 
#     # print(Text)
#     pdf_writer=pdf.PdfFileWriter()
#     if  re.search(String2, Text) != None:
#         print("This is page " + str(i))
#         page=object.getPage(i)
#         pdf_writer=pdf.PdfFileWriter()
#         pdf_writer.addPage(page)
#         output=open('cashflow17181old.pdf','wb')
#         pdf_writer.write(output)
#     output.close()

# %% [markdown]
# # Aurobindo Pharma for 2018-2019

# %% [markdown]
# ## Balance Sheet

# %%
# open the pdf file
object = pdf.PdfFileReader("APL-Annual-Report-2018-19.pdf")

# get number of pages
NumPages = object.getNumPages()

# define keyterms
String = "STANDALONE BALANCE SHEET"
# String1 = "STANDALONE STATEMENT OF PROFIT AND LOSS"
# String2 = "STANDALONE STATEMENT OF CASH FLOW"
# extract text and do the search
for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
    # print(Text)
    if  re.search(String, Text) != None:
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer=pdf.PdfFileWriter()
        pdf_writer.addPage(page)
        output=open('balancesheet_aurobindo1819.pdf','wb')
        pdf_writer.write(output)
        output.close()
        df_bl1819=read_pdf('balancesheet_aurobindo1819.pdf')
df_bl1819[0]
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# This is page 143
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0         NaN                                                NaN       Note
# 1         NaN                                                NaN        NaN
# 2           I                                             ASSETS        NaN
# 3         NaN                                 Non-current assets        NaN
# 4         NaN                  (a) Property, plant and equipment       3(A)
# 5         NaN                       (b) Capital work-in-progress       3(A)
# 6         NaN                              (c) Intangible assets       3(B)
# 7         NaN            (d) Intangible assets under development       3(B)
# 8         NaN                               (e) Financial assets        NaN
# 9         NaN                                    (i) Investments       4(A)
# ...

# %% [markdown]
# ## P&L Statement

# %%
# open the pdf file
object = pdf.PdfFileReader("APL-Annual-Report-2018-19.pdf")

# get number of pages
NumPages = object.getNumPages()

String1 = "STANDALONE STATEMENT OF PROFIT AND LOSS"

for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
    # print(Text)
    if  re.search(String1, Text) != None:
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer=pdf.PdfFileWriter()
        pdf_writer.addPage(page)
        output=open('p&l_aurobindo_1819.pdf','wb')
        pdf_writer.write(output)
        output.close()
        df_pl1819=read_pdf('p&l_aurobindo_1819.pdf')
df_pl1819[0]
print(tabulate(df_pl1819[0]))
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# This is page 144
# --  ----  --------------------------------------------------------------------------------  ----  -------------  -------------
#  0  nan   nan                                                                               Note  nan            nan
#  1  nan   nan                                                                               nan   31 March 2019  31 March 2018
#  2  I     INCOME                                                                            nan   nan            nan
#  3  nan   Revenue from operations                                                           20    122,578.9      103,031.5
#  4  nan   Other income                                                                      21    1,992.2        806.5
#  5  nan   TOTAL INCOME (I)                                                                  nan   124,571.1      103,838.0
# ...

# %% [markdown]
# ## Cash Flow Statement

# %%
# open the pdf file
object = pdf.PdfFileReader("APL-Annual-Report-2018-19.pdf")
# get number of pages
NumPages = object.getNumPages()

String2 = "STANDALONE STATEMENT OF CASH FLOW"

for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
    # print(Text)
    pdf_writer=pdf.PdfFileWriter()
    if  re.search(String2, Text) != None:
        print("This is page " + str(i))
        page=object.getPage(i)
#         pdf_writer=pdf.PdfFileWriter()
        pdf_writer.addPage(page)
        output=open('cashflow1.pdf','wb')
        pdf_writer.write(output)
    output.close()
# Out:
# This is page 146
# This is page 147

# %% [markdown]
# # Aurobindo Pharma 16-17

# %% [markdown]
# ## Balance Sheet

# %%
# open the pdf file
object = pdf.PdfFileReader("Annual-Report-2016-17.pdf")

# get number of pages
NumPages = object.getNumPages()

# define keyterms
String = "Balance Sheet as at March 31, 2017"
# String1 = "STANDALONE STATEMENT OF PROFIT AND LOSS"
# String2 = "STANDALONE STATEMENT OF CASH FLOW"
# extract text and do the search
for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
    # print(Text)
    if  re.search(String, Text) != None:
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer=pdf.PdfFileWriter()
        pdf_writer.addPage(page)
        output=open('balancesheet_aurobindo1617.pdf','wb')
        pdf_writer.write(output)
        output.close()
        df_bl1617=read_pdf('balancesheet_aurobindo1617.pdf')
df_bl1617[0]
# Out:
# ...
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# This is page 110
# Got stderr: Jan 30, 2020 9:23:09 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font ArialMT for OfficinaSans-Book
# Jan 30, 2020 9:23:09 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font Arial-BoldMT for OfficinaSans-Bold
# Jan 30, 2020 9:23:09 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font ArialMT for OfficinaSans-Book
# Jan 30, 2020 9:23:09 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font Arial-BoldMT for OfficinaSans-Bold
# Jan 30, 2020 9:23:10 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font ArialMT for OfficinaSans-Book
# Jan 30, 2020 9:23:10 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font Arial-BoldMT for OfficinaSans-Bold
#
# ...

# %%
# open the pdf file
object = pdf.PdfFileReader("Annual-Report-2016-17.pdf")

# get number of pages
NumPages = object.getNumPages()

# define keyterms
String = "K. Nithyananda Reddy"
# String1 = "STANDALONE STATEMENT OF PROFIT AND LOSS"
# String2 = "STANDALONE STATEMENT OF CASH FLOW"
# extract text and do the search
for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
    # print(Text)
    if  re.search(String, Text) != None:
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer=pdf.PdfFileWriter()
        pdf_writer.addPage(page)
        output=open('vicechairmanspeech.pdf','wb')
        pdf_writer.write(output)
        output.close()
# Out:
# This is page 8
# This is page 71
# This is page 82
# This is page 88
# This is page 94
# This is page 95
# This is page 96
# This is page 97
# This is page 98
# This is page 100
# This is page 101
# This is page 148
# This is page 152
# This is page 205
# This is page 206

# %%
# !pip install fitz
# import fitz

# filename = "Annual-Report-2017-18.pdf"
# search_term = "K. Nithyananda Reddy"
# pdf_document = fitz.open(filename)

# for current_page in range(len(pdf_document)):
#     page = pdf_document.loadPage(current_page)
#     if page.searchFor(search_term):
#         print("%s found on page %i" % (search_term, current_page))

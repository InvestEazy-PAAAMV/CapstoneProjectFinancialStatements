# %% [markdown]
# # Initialization of packages

# %%
from tabula import read_pdf
from tabulate import tabulate
import PyPDF2
import camelot

# %% [markdown]
# # For 2016-17

# %% [markdown]
# ## Consolidated Balance Sheet

# %%
# open the pdf file
object = pdf.PdfFileReader("01-09-2017_be12d_AR_2016_17.pdf")

# get number of pages
NumPages = object.getNumPages()

# define keyterms
String1 = "CONSOLIDATED BALANCE SHEET"
String2 = "Signatures to the Consolidated Balance Sheet"
# extract text and do the search
for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
    # print(Text)
    if  re.search(String1, Text) != None and re.search(String2, Text) != None:
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer=pdf.PdfFileWriter()
        pdf_writer.addPage(page)
        output=open('balancesheet_1617.pdf','wb')
        pdf_writer.write(output)
        output.close()
        df=read_pdf('balancesheet_1617.pdf')
print(tabulate(df[0]))
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# This is page 149
# --  ---------------------------------------------------------------------------  -----------
#  0  CONSOLIDATED BALANCE SHEET                                                   nan
#     (` in crores)
#     As atAs atAs at
#     Notes
#     31-Mar-201731-Mar-20161-Apr-2015
#     ASSETS
#     Non-current assets
#     Property, plant and equipment6
#     1,871.41975.15882.63
#     Capital work-in-progress
#     519.491,041.58678.33
#     Goodwill7
#     159.50124.88124.88
#     Other intangible assets8
#     1,657.531,759.051,786.17
#     Financial assets
#     Investments9
#     0.090.090.06
#     Loans10
#     2.161.130.99
#     Other financial assets11
#     105.1268.5362.01
#     107.3769.7563.06
#     Deferred tax assets (net)20
#     309.88283.19266.74
#     Other non-current assets12
#     115.62115.2563.81
#     4,740.804,368.853,865.62
#     Current assets
#     Inventories13
# ...

# %% [markdown]
# ## Consolidated Profit and Loss Statement

# %%
# open the pdf file
object = pdf.PdfFileReader("01-09-2017_be12d_AR_2016_17.pdf")

# get number of pages
NumPages = object.getNumPages()

# define keyterms
String1 = "CONSOLIDATED STATEMENT OF PROFIT AND LOSS"
String2 = "Signatures to the Consolidated Statement of Profit and Loss"
# extract text and do the search
for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
    # print(Text)
    if  re.search(String1, Text) != None and re.search(String2, Text) != None:
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer=pdf.PdfFileWriter()
        pdf_writer.addPage(page)
        output=open('p&l_1617.pdf','wb')
        pdf_writer.write(output)
        output.close()
        df=camelot.read_pdf('p&l_1617.pdf')
df
# Out:
# [                                           Unnamed: 0          Unnamed: 1
#  0   CONSOLIDATED BALANCE SHEET\r(` in crores)\rAs ...                 NaN
#  1                          CONSOLIDATED BALANCE SHEET                 NaN
#  2                                                 NaN  As at\r31-Mar-2017
#  3                                                 NaN                 NaN
#  4                                                 NaN                 NaN
#  5                                                 NaN            1,871.41
#  6                                                 NaN              519.49
#  7                                                 NaN              159.50
#  8                                                 NaN            1,657.53
#  9                                                 NaN                 NaN
#  10                                                NaN                0.09
# ...

# %% [markdown]
# ## Consolidated Cash Flow Statement

# %%
object = pdf.PdfFileReader("01-09-2017_be12d_AR_2016_17.pdf")

# get number of pages
NumPages = object.getNumPages()
String1 = "CONSOLIDATED CASH FLOW STATEMENT"
String2 = "Signatures to the Consolidated Cash Flow Statement"
pdf_writer=pdf.PdfFileWriter()
for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
    # print(Text)
    if  re.search(String1, Text) != None and re.search(String2, Text) != None:
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer.addPage(page)
output=open('cashflow_1617.pdf','wb')
pdf_writer.write(output)
output.close()
df2=read_pdf('cashflow_1617.pdf',pages="all")
df2
# Out:
# This is page 152
# ...

# %% [markdown]
# # For 2017-18

# %% [markdown]
# ## Consolidated Balance Sheet

# %%
# open the pdf file
object = pdf.PdfFileReader("AR-2017-18.pdf")

# get number of pages
NumPages = object.getNumPages()

# define keyterms
String1 = "CONSOLIDATED BALANCE SHEET"
# String2 = "VP (Legal) & Company Secretary"
# extract text and do the search
for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
#     print(Text)
    
    if  re.search(String1, Text) != None:
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer=pdf.PdfFileWriter()
        pdf_writer.addPage(page)
        output=open('balancesheet_1718.pdf','wb')
        pdf_writer.write(output)
        output.close()
df1=read_pdf('balancesheet_1718.pdf')
df1[0]
# Out:
# This is page 157
# 'pages' argument isn't specified.Will extract only from page 1 by default.
#                                            Unnamed: 0          Unnamed: 1
# 0   CONSOLIDATED BALANCE SHEET\r(` in crores)\rNot...                 NaN
# 1                          CONSOLIDATED BALANCE SHEET                 NaN
# 2                                                 NaN  As at\r31-Mar-2018
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# 5                                                 NaN            2,416.80
# 6                                                 NaN              423.21
# 7                                                 NaN              398.52
# 8                                                 NaN            5,039.36
# 9                                                 NaN              223.73
# ...

# %% [markdown]
# ## Consolidated Profit and Loss Statement

# %%
# open the pdf file
object = pdf.PdfFileReader("AR-2017-18.pdf")

# get number of pages
NumPages = object.getNumPages()

# define keyterms
String1 = "CONSOLIDATED STATEMENT OF PROFIT AND LOSS"
# String2 = "Signatures to the Consolidated Statement of Profit and Loss"
# extract text and do the search
for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
    # print(Text)
    if  re.search(String1, Text) != None :
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer=pdf.PdfFileWriter()
        pdf_writer.addPage(page)
        output=open('p&l_1718.pdf','wb')
        pdf_writer.write(output)
        output.close()
        df=camelot.read_pdf('p&l_1718.pdf')
df
# Out:
# This is page 158
# <TableList n=0>

# %% [markdown]
# ## Consolidated Cash Flow Statement

# %%
object = pdf.PdfFileReader("AR-2017-18.pdf")

# get number of pages
NumPages = object.getNumPages()
String1 = "CONSOLIDATED CASH FLOW STATEMENT"
# String2 = "Firm's Registration No. 101248W/W-100022"
pdf_writer=pdf.PdfFileWriter()
for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
    # print(Text)
    if  re.search(String1, Text) != None  :
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer.addPage(page)
output=open('cashflow_1718.pdf','wb')
pdf_writer.write(output)
output.close()
# Out:
# This is page 160

# %% [markdown]
# # For 2018-19

# %% [markdown]
# ## Consolidated Balanced Sheet

# %% [markdown]
# not working

# %%
# open the pdf file
object = pdf.PdfFileReader("AR-2018-19.pdf")

# get number of pages
NumPages = object.getNumPages()

# define keyterms
String1 = "CONSOLIDATED BALANCE SHEET"
# String2 = "EQUITY AND LIABILITIES"
# String3 = "Mahesh Agrawal"
# extract text and do the search
for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
#     print(Text)
    
    if  re.search(String1, Text) != None :
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer=pdf.PdfFileWriter()
        pdf_writer.addPage(page)
        output=open('balancesheet_1819.pdf','wb')
        pdf_writer.write(output)
        output.close()
df1=read_pdf('balancesheet_1819.pdf')
df1[0]
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# Got stderr: Feb 04, 2020 9:54:22 PM org.apache.pdfbox.contentstream.operator.state.SetGraphicsStateParameters process
# SEVERE: name for 'gs' operator not found in resources: /GS0
# Feb 04, 2020 9:54:22 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Missing color space: CS0
# Feb 04, 2020 9:54:22 PM org.apache.pdfbox.contentstream.operator.state.SetGraphicsStateParameters process
# SEVERE: name for 'gs' operator not found in resources: /GS0
# Feb 04, 2020 9:54:22 PM org.apache.pdfbox.contentstream.PDFStreamEngine showText
# WARNING: No current font, will use default
# Feb 04, 2020 9:54:23 PM org.apache.pdfbox.contentstream.PDFStreamEngine showText
# WARNING: No current font, will use default
# Feb 04, 2020 9:54:23 PM org.apache.pdfbox.contentstream.PDFStreamEngine showText
# WARNING: No current font, will use default
# ...

# %% [markdown]
# ## Consolidated Profit and Loss Statement

# %% [markdown]
# not working

# %%
# open the pdf file
object = pdf.PdfFileReader("AR-2018-19.pdf")

# get number of pages
NumPages = object.getNumPages()

# define keyterms
String1 = "CONSOLIDATED STATEMENT OF PROFIT AND LOSS"
String2 = "7,729.85"
String3 = "6,811.18"
# extract text and do the search
for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
    # print(Text)
    if  (re.search(String1, Text) != None 
         and re.search(String2, Text) != None and re.search(String3,Text)!= None) :
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer=pdf.PdfFileWriter()
        pdf_writer.addPage(page)
        output=open('p&l_1819.pdf','wb')
        pdf_writer.write(output)
        output.close()
        df=camelot.read_pdf('p&l_1819.pdf')
df
# Out:
# <TableList n=0>

# %% [markdown]
# ## Consolidated Statement of Cash Flow

# %% [markdown]
# Not Working

# %%
object = pdf.PdfFileReader("AR-2018-19.pdf")

# get number of pages
NumPages = object.getNumPages()
String1 = "CONSOLIDATED CASH FLOW STATEMENT"
# String2 = "Firm's Registration No. 101248W/W-100022"
pdf_writer=pdf.PdfFileWriter()
for i in range(0, NumPages):
    PageObj = object.getPage(i)
    Text = PageObj.extractText() 
    # print(Text)
    if  re.search(String1, Text) != None  :
        print("This is page " + str(i))
        page=object.getPage(i)
        pdf_writer.addPage(page)
output=open('cashflow_1819.pdf','wb')
pdf_writer.write(output)
output.close()
